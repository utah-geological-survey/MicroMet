# %%
import pandas as pd
from micromet.spectral import *

# %%
# Generate and analyze example data
df, results, (fig, axes) = demo_spectral_analysis()



# Display plots
import matplotlib.pyplot as plt

plt.show()
# Out:
# Dataset properties:
# --------------------
# Duration: 30.0 minutes
# Sampling frequency: 20.0 Hz
#
# Mean values:
# Ux     3.999379
# Uy     0.000611
# Uz     0.000418
# Ts    25.000054
# pV    10.000421
# dtype: float64
#
# Standard deviations:
# Ux    0.679969
# Uy    0.444556
# Uz    0.283498
# Ts    1.478151
# pV    0.796489
# dtype: float64

# %%
df, fig = example_wt_cospectra()
plt.show()

# %%
# Generate example with slope line
df, fig = example_wt_cospectra(show_slope=True)
plt.show()
