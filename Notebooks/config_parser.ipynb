# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import pathlib
from configparser import ConfigParser

import polars as pl
import json
import re

from sklearn.experimental import enable_iterative_imputer  # noqa
from sklearn.impute import IterativeImputer

import warnings
warnings.filterwarnings('ignore')

# %%
import sys
sys.path.append("../../micromet")
import micromet
from micromet import AmerifluxDataProcessor

# %%
def filter_polars_df_iqr(df, 
                         column_name, 
                         lower_quant = 0.05, 
                         upper_quant= 0.95, 
                         multiplier=1., 
                         filter_rows=True,
                         replace_value=None 
                         ):
    """
    Filters a Polars DataFrame based on the IQR method for outlier detection.
    
    Parameters:
    df (pl.DataFrame): The Polars DataFrame to filter.
    column_name (str): The name of the column to apply the IQR filter on.
    
    Returns:
    pl.DataFrame: The filtered DataFrame.
    """
    q1 = df.select(pl.col(column_name).quantile(lower_quant)).item()
    q3 = df.select(pl.col(column_name).quantile(upper_quant)).item()
    iqr = q3 - q1

    lower_bound = q1 - multiplier * iqr
    upper_bound = q3 + multiplier * iqr

    if filter_rows:
        return df.filter(
            (pl.col(column_name) >= lower_bound) & (pl.col(column_name) <= upper_bound)
        )

    else:
        return df.with_columns(
            pl.when(pl.col(column_name) < lower_bound)
            .then(replace_value)
            .when(pl.col(column_name) > upper_bound)
            .then(replace_value)
            .otherwise(pl.col(column_name)).alias(column_name)
        )

# %%
import pandas as pd
import re

def replace_negative_values(df, column_name, filter_column=None, threshold=0.85, replace_value=0):
    """
    Replace negative values in a specified column of a DataFrame with 0.

    Parameters:
        df (pd.DataFrame): The DataFrame to process.
        column_name (str): The name of the column to check for negative values.

    Returns:
        pd.DataFrame: The DataFrame with negative values replaced by 0.
    """
    if filter_column:
        filter_column = filter_column
    else:
        filter_column = column_name


    df = df.with_columns(
        pl.when(pl.col(filter_column) < threshold)
        .then(replace_value)
        .otherwise(pl.col(column_name))
        .alias(column_name)
    )
    return df

def parse_datetimes_with_decimal_seconds(datetime_series):
    """
    Parse datetime strings that may have optional or missing fractional seconds,
    and normalize them so all include a decimal part.

    Parameters:
        datetime_series (pd.Series or list-like): Datetime strings in format
        'YYYY-MM-DD HH:MM:SS', 'YYYY-MM-DD HH:MM:SS.', or 'YYYY-MM-DD HH:MM:SS.ssssss'.

    Returns:
        pd.Series: Parsed datetime values with consistent fractional seconds.
    """
    def normalize_timestamp(ts):
        ts = ts.strip()
        # Remove trailing dot if no digits follow
        ts = re.sub(r'(?<=\d{2}:\d{2}:\d{2})\.(?!\d)', '', ts)
        # If it ends right after the seconds, append ".0"
        if re.match(r'^\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2}$', ts):
            ts += '.0'
        return ts

    cleaned = datetime_series.map(normalize_timestamp)
    return pd.to_datetime(cleaned, format="%Y-%m-%d %H:%M:%S.%f")



# Example usage
example = [
    "2023-10-27 15:59:55",
    "2023-10-27 15:59:55.",
    "2023-10-27 15:59:55.123456",
    "2023-10-27 00:00:00"
]

df = pd.DataFrame({'TIMESTAMP': example})
df['parsed'] = parse_datetimes_with_decimal_seconds(df['TIMESTAMP'])
print(df)
# Out:
#                     TIMESTAMP                     parsed
# 0         2023-10-27 15:59:55 2023-10-27 15:59:55.000000
# 1        2023-10-27 15:59:55. 2023-10-27 15:59:55.000000
# 2  2023-10-27 15:59:55.123456 2023-10-27 15:59:55.123456
# 3         2023-10-27 00:00:00 2023-10-27 00:00:00.000000

# %%
from micromet import convert_file
import pathlib
import os

input_dir = pathlib.Path("E:/UGS_Flux/Data_Downloads/")
output_format = "toa5"
format_options = "1"


for file in input_dir.rglob("*Time_Series*.dat"): 

    cr_sn = str(file.stem).split("_")[0]
    file_no = str(file.stem).split("_")[-1]
    file_dir = file.parent
    output_file = file_dir / f"{cr_sn}_{file_no}.asc"
    if output_file.exists():
        print(f"File {output_file} already exists. Skipping conversion.")
        continue
    print(f"Converting {file} to {output_file}")    
    convert_file(file, output_file, output_format, format_options)

# %%
input_dir = pathlib.Path("E:/UGS_Flux/Data_Downloads/")
output_format = "toa5"
format_options = "1"


for file in input_dir.rglob("*Time_Series*.dat"): 

    cr_sn = str(file.stem).split("_")[0]
    file_no = str(file.stem).split("_")[-1]
    file_dir = file.parent
    output_file = file_dir / f"{cr_sn}_{file_no}.asc"
    if output_file.exists():
        print(f"File {output_file} already exists. Skipping conversion.")
        continue
    print(f"Converting {file} to {output_file}")    
    convert_file(file, output_file, output_format, format_options)
# Out:
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_0.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_1.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_10.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_100.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_101.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_102.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_103.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_104.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_105.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_106.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_107.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_108.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_109.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_11.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_110.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_111.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_112.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_113.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_114.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_115.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_116.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_117.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_118.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_119.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_12.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_120.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_121.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_122.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_123.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_124.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_125.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_126.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_127.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_128.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_129.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_13.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_130.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_131.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_132.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_133.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_134.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_135.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_136.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_137.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_138.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_139.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_14.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_140.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_141.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_142.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_143.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_144.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_145.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_146.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_147.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_148.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_149.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_15.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_150.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_151.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_152.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_153.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_154.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_155.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_156.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_157.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_158.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_159.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_16.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_160.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_161.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_162.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_163.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_164.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_165.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_166.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_167.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_168.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_169.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_17.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_170.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_171.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_172.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_173.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_174.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_175.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_176.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_177.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_178.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_179.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_18.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_180.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_181.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_182.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_183.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_184.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_185.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_186.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_187.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_188.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_189.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_19.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_190.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_191.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_192.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_193.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_194.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_195.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_196.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_197.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_198.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_199.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_2.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_20.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_200.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_201.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_202.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_203.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_204.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_205.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_206.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_207.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_208.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_209.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_21.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_210.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_211.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_212.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_213.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_214.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_215.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_216.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_217.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_218.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_219.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_22.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_220.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_221.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_222.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_223.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_224.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_225.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_226.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_227.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_228.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_229.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_23.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_230.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_231.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_232.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_233.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_234.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_235.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_236.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_237.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_238.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_239.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_24.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_240.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_241.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_242.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_243.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_244.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_245.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_246.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_247.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_248.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_249.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_25.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_250.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_251.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_252.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_253.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_26.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_27.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_28.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_29.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_3.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_30.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_31.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_32.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_33.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_34.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_35.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_36.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_37.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_38.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_39.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_4.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_40.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_41.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_42.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_43.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_44.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_45.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_46.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_47.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_48.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_49.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_5.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_50.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_51.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_52.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_53.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_54.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_55.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_56.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_57.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_58.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_59.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_6.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_60.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_61.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_62.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_63.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_64.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_65.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_66.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_67.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_68.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_69.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_7.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_70.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_71.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_72.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_73.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_74.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_75.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_76.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_77.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_78.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_79.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_8.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_80.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_81.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_82.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_83.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_84.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_85.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_86.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_87.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_88.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_89.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_9.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_90.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_91.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_92.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_93.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_94.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_95.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_96.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_97.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_98.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Bluff\21020_99.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_0.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_1.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_10.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_100.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_101.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_102.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_103.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_104.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_105.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_106.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_107.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_108.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_109.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_11.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_110.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_111.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_112.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_113.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_114.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_115.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_116.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_117.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_118.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_119.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_12.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_120.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_121.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_122.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_123.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_124.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_125.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_126.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_127.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_128.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_129.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_13.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_130.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_131.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_132.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_133.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_134.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_135.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_136.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_137.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_138.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_139.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_14.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_140.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_141.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_142.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_143.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_144.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_145.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_146.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_147.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_148.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_149.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_15.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_150.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_151.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_152.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_153.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_154.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_155.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_156.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_157.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_158.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_159.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_16.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_160.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_161.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_162.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_163.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_164.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_165.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_166.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_167.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_168.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_169.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_17.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_170.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_171.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_172.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_173.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_174.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_175.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_176.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_177.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_178.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_179.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_18.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_180.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_181.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_182.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_183.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_184.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_185.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_186.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_187.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_188.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_189.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_19.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_190.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_191.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_192.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_193.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_194.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_195.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_196.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_197.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_198.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_199.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_2.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_20.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_200.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_201.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_202.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_203.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_204.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_205.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_206.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_207.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_208.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_209.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_21.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_210.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_211.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_212.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_213.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_214.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_215.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_216.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_217.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_218.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_219.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_22.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_220.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_221.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_222.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_223.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_224.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_225.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_226.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_227.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_228.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_229.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_23.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_230.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_231.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_232.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_233.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_234.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_235.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_236.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_237.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_238.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_239.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_24.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_240.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_241.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_242.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_243.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_244.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_245.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_246.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_247.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_248.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_249.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_25.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_250.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_251.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_252.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_253.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_254.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_255.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_256.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_257.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_258.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_259.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_26.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_260.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_261.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_262.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_263.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_264.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_265.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_266.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_267.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_268.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_269.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_27.asc already exists. Skipping conversion.
# File E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_270.asc already exists. Skipping conversion.
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_271.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_271.asc
# Conversion successful.
# Converted 864000 records in 26250 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_272.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_272.asc
# Conversion successful.
# Converted 864000 records in 27547 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_273.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_273.asc
# Conversion successful.
# Converted 864000 records in 26641 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_274.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_274.asc
# Conversion successful.
# Converted 864000 records in 26344 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_275.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_275.asc
# Conversion successful.
# Converted 864000 records in 25281 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_276.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_276.asc
# Conversion successful.
# Converted 864000 records in 24531 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_277.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_277.asc
# Conversion successful.
# Converted 864000 records in 24656 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_278.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_278.asc
# Conversion successful.
# Converted 864000 records in 25063 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_279.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_279.asc
# Conversion successful.
# Converted 864000 records in 24641 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_28.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_28.asc
# Conversion successful.
# Converted 864000 records in 25578 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_280.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_280.asc
# Conversion successful.
# Converted 864000 records in 24594 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_281.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_281.asc
# Conversion successful.
# Converted 864000 records in 24297 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_282.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_282.asc
# Conversion successful.
# Converted 864000 records in 25140 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_283.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_283.asc
# Conversion successful.
# Converted 864000 records in 24469 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_284.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_284.asc
# Conversion successful.
# Converted 864000 records in 25562 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_285.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_285.asc
# Conversion successful.
# Converted 864000 records in 25781 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_286.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_286.asc
# Conversion successful.
# Converted 864000 records in 25032 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_287.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_287.asc
# Conversion successful.
# Converted 864000 records in 24188 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_288.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_288.asc
# Conversion successful.
# Converted 864000 records in 25047 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_289.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_289.asc
# Conversion successful.
# Converted 864000 records in 25844 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_29.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_29.asc
# Conversion successful.
# Converted 864000 records in 25593 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_290.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_290.asc
# Conversion successful.
# Converted 864000 records in 24094 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_291.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_291.asc
# Conversion successful.
# Converted 864000 records in 28313 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_292.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_292.asc
# Conversion successful.
# Converted 864000 records in 26985 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_293.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_293.asc
# Conversion successful.
# Converted 864000 records in 28109 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_294.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_294.asc
# Conversion successful.
# Converted 864000 records in 31063 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_295.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_295.asc
# Conversion successful.
# Converted 864000 records in 26843 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_296.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_296.asc
# Conversion successful.
# Converted 864000 records in 27828 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_297.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_297.asc
# Conversion successful.
# Converted 864000 records in 32266 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_298.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_298.asc
# Conversion successful.
# Converted 864000 records in 29719 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_299.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_299.asc
# Conversion successful.
# Converted 864000 records in 28891 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_3.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_3.asc
# Conversion successful.
# Converted 862443 records in 22422 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_30.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_30.asc
# Conversion successful.
# Converted 864000 records in 28141 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_300.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_300.asc
# Conversion successful.
# Converted 864000 records in 30984 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_301.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_301.asc
# Conversion successful.
# Converted 864000 records in 27891 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_302.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_302.asc
# Conversion successful.
# Converted 864000 records in 28719 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_303.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_303.asc
# Conversion successful.
# Converted 864000 records in 29015 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_304.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_304.asc
# Conversion successful.
# Converted 864000 records in 28250 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_Time_Series_305.dat to E:\UGS_Flux\Data_Downloads\Cedar_Mesa\21313_305.asc
# Conversion successful.
# ...
# Converted 710229 records in 25797 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_135.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_135.asc
# Conversion successful.
# Converted 153492 records in 4969 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_136.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_136.asc
# Conversion successful.
# Converted 864000 records in 30000 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_137.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_137.asc
# Conversion successful.
# Converted 864000 records in 29610 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_138.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_138.asc
# Conversion successful.
# Converted 864000 records in 30437 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_139.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_139.asc
# Conversion successful.
# Converted 864000 records in 28656 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_14.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_14.asc
# Conversion successful.
# Converted 864000 records in 30109 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_140.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_140.asc
# Conversion successful.
# Converted 864000 records in 29110 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_141.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_141.asc
# Conversion successful.
# Converted 864000 records in 29234 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_142.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_142.asc
# Conversion successful.
# Converted 864000 records in 28578 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_143.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_143.asc
# Conversion successful.
# Converted 864000 records in 26781 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_144.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_144.asc
# Conversion successful.
# Converted 864000 records in 31000 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_145.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_145.asc
# Conversion successful.
# Converted 864000 records in 28735 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_146.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_146.asc
# Conversion successful.
# Converted 864000 records in 28000 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_147.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_147.asc
# Conversion successful.
# Converted 864000 records in 28578 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_148.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_148.asc
# Conversion successful.
# Converted 864000 records in 29047 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_149.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_149.asc
# Conversion successful.
# Converted 864000 records in 28937 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_15.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_15.asc
# Conversion successful.
# Converted 864000 records in 30312 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_150.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_150.asc
# Conversion successful.
# Converted 864000 records in 30234 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_151.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_151.asc
# Conversion successful.
# Converted 864000 records in 27328 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_152.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_152.asc
# Conversion successful.
# Converted 864000 records in 29547 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_153.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_153.asc
# Conversion successful.
# Converted 864000 records in 28750 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_154.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_154.asc
# Conversion successful.
# Converted 864000 records in 29172 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_155.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_155.asc
# Conversion successful.
# Converted 864000 records in 28187 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_156.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_156.asc
# Conversion successful.
# Converted 864000 records in 28969 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_157.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_157.asc
# Conversion successful.
# Converted 864000 records in 27390 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_158.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_158.asc
# Conversion successful.
# Converted 864000 records in 28282 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_159.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_159.asc
# Conversion successful.
# Converted 864000 records in 29906 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_16.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_16.asc
# Conversion successful.
# Converted 864000 records in 25016 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_160.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_160.asc
# Conversion successful.
# Converted 864000 records in 25141 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_161.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_161.asc
# Conversion successful.
# Converted 864000 records in 24359 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_162.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_162.asc
# Conversion successful.
# Converted 864000 records in 24563 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_163.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_163.asc
# Conversion successful.
# Converted 864000 records in 25188 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_164.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_164.asc
# Conversion successful.
# Converted 864000 records in 27437 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_165.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_165.asc
# Conversion successful.
# Converted 864000 records in 27297 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_166.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_166.asc
# Conversion successful.
# Converted 864000 records in 26704 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_167.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_167.asc
# Conversion successful.
# Converted 864000 records in 26390 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_168.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_168.asc
# Conversion successful.
# Converted 864000 records in 26516 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_169.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_169.asc
# Conversion successful.
# Converted 864000 records in 27297 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_17.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_17.asc
# Conversion successful.
# Converted 543485 records in 17204 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_170.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_170.asc
# Conversion successful.
# Converted 864000 records in 26813 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_171.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_171.asc
# Conversion successful.
# Converted 864000 records in 25563 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_172.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_172.asc
# Conversion successful.
# Converted 864000 records in 25156 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_173.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_173.asc
# Conversion successful.
# Converted 864000 records in 25406 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_174.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_174.asc
# Conversion successful.
# Converted 864000 records in 25188 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_175.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_175.asc
# Conversion successful.
# Converted 864000 records in 26109 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_176.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_176.asc
# Conversion successful.
# Converted 864000 records in 25781 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_177.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_177.asc
# Conversion successful.
# Converted 864000 records in 25484 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_178.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_178.asc
# Conversion successful.
# Converted 864000 records in 25672 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_179.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_179.asc
# Conversion successful.
# Converted 864000 records in 25453 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_18.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_18.asc
# Conversion successful.
# Converted 16032 records in 516 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_180.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_180.asc
# Conversion successful.
# Converted 864000 records in 26656 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_181.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_181.asc
# Conversion successful.
# Converted 864000 records in 25781 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_182.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_182.asc
# Conversion successful.
# Converted 864000 records in 28485 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_183.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_183.asc
# Conversion successful.
# Converted 864000 records in 27000 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_184.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_184.asc
# Conversion successful.
# Converted 864000 records in 26375 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_185.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_185.asc
# Conversion successful.
# Converted 864000 records in 27250 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_186.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_186.asc
# Conversion successful.
# Converted 864000 records in 27812 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_187.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_187.asc
# Conversion successful.
# Converted 864000 records in 26687 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_188.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_188.asc
# Conversion successful.
# Converted 864000 records in 29282 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_189.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_189.asc
# Conversion successful.
# Converted 864000 records in 26437 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_19.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_19.asc
# Conversion successful.
# Converted 303975 records in 8953 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_190.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_190.asc
# Conversion successful.
# Converted 864000 records in 25516 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_191.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_191.asc
# Conversion successful.
# Converted 864000 records in 27984 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_192.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_192.asc
# Conversion successful.
# Converted 864000 records in 28734 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_193.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_193.asc
# Conversion successful.
# Converted 864000 records in 24984 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_194.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_194.asc
# Conversion successful.
# Converted 864000 records in 24765 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_195.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_195.asc
# Conversion successful.
# Converted 864000 records in 24891 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_196.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_196.asc
# Conversion successful.
# Converted 864000 records in 25406 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_197.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_197.asc
# Conversion successful.
# Converted 864000 records in 26094 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_198.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_198.asc
# Conversion successful.
# Converted 864000 records in 26141 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_199.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_199.asc
# Conversion successful.
# Converted 864000 records in 27531 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_2.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_2.asc
# Conversion successful.
# Converted 11712 records in 250 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_20.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_20.asc
# Conversion successful.
# Converted 864000 records in 26734 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_200.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_200.asc
# Conversion successful.
# Converted 864000 records in 27047 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_201.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_201.asc
# Conversion successful.
# Converted 864000 records in 27156 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_202.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_202.asc
# Conversion successful.
# Converted 864000 records in 25469 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_203.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_203.asc
# Conversion successful.
# Converted 864000 records in 25031 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_204.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_204.asc
# Conversion successful.
# Converted 864000 records in 26313 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_205.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_205.asc
# Conversion successful.
# Converted 864000 records in 26016 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_206.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_206.asc
# Conversion successful.
# Converted 864000 records in 24578 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_207.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_207.asc
# Conversion successful.
# Converted 864000 records in 30344 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_208.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_208.asc
# Conversion successful.
# Converted 864000 records in 26687 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_209.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_209.asc
# Conversion successful.
# Converted 864000 records in 25125 msec
#
# Converting E:\UGS_Flux\Data_Downloads\Escalante\21021_Time_Series_21.dat to E:\UGS_Flux\Data_Downloads\Escalante\21021_21.asc

# %%
# Step 1 & 2: Read lines manually to get column names and units
with open(output_file, 'r') as f:
    lines = f.readlines()
    column_names = [col.strip().strip('"') for col in lines[1].split(",")]
    units = [unit.strip().strip('"') for unit in lines[2].split(",")]

# Step 3: Create a units dictionary
unit_map = dict(zip(column_names, units))

# Step 4: Read data using polars, skipping 4 lines and setting column names
df = pl.read_csv(
    output_file,
    skip_rows=4,
    has_header=False,  # because we are setting our own column names
    new_columns=column_names,
    quote_char='"',
    try_parse_dates=True
)



for col in df.columns:
    if col != "TIMESTAMP":
        print(col, df[col].dtype)
        df = filter_polars_df_iqr(df, col, filter_rows=False)

df = replace_negative_values(df, 'H2O_density', filter_column='H2O_sig_strgth', threshold=0.85, replace_value=0)
#df["TIMESTAMP"] = parse_polars_datetimes_with_decimal_seconds(df['TIMESTAMP'])
# Step 1: Convert Polars → Pandas
df_pd = df.to_pandas()
df_pd["TIMESTAMP"] = parse_datetimes_with_decimal_seconds(df_pd["TIMESTAMP"])



# Save the units dictionary to a JSON file
with open("units.json", "w") as f:
    json.dump(unit_map, f, indent=2)

df_pd = df_pd.set_index(["TIMESTAMP"])
df_resamp = df_pd.resample("100L").asfreq()

# Step 2: Impute with IterativeImputer
imputer = IterativeImputer(random_state=0)
df_imputed_pd = pd.DataFrame(imputer.fit_transform(df_resamp), 
                             columns=df_resamp.columns, 
                             index=df_resamp.index)



df_imputed = pl.from_pandas(df_imputed_pd)

df_imputed = replace_negative_values(df_imputed, 'H2O_density')

datalogger = str(input_file.stem).split("_")[0]
fileno = str(input_file.stem).split("_")[-1] 
first_date = df_imputed_pd.first_valid_index()
minutes = round((df_imputed_pd.last_valid_index() - df_imputed_pd.first_valid_index()).seconds/60,0) 
meas_freq = len(df_imputed_pd)/(minutes*60) # Hz
first_date

df_imputed.write_csv(f"{datalogger}_imputed_{fileno}_{first_date:%Y_%m_%d_%H%M}.csv")
# Out:
# RECORD Int64
# Ux Float64
# Uy Float64
# Uz Float64
# T_SONIC Float64
# diag_sonic Int64
# CO2_density Float64
# CO2_density_fast_tmpr Float64
# H2O_density Float64
# diag_irga Int64
# T_SONIC_corr Float64
# TA_1_1_1 Float64
# PA Float64
# CO2_sig_strgth Float64
# H2O_sig_strgth Float64

# %%
unit_map
# Out:
# {'TIMESTAMP': 'TS',
#  'RECORD': 'RN',
#  'Ux': 'm s-1',
#  'Uy': 'm s-1',
#  'Uz': 'm s-1',
#  'T_SONIC': 'deg C',
#  'diag_sonic': 'adimensional',
#  'CO2_density': 'mg m-3',
#  'CO2_density_fast_tmpr': '',
#  'H2O_density': 'g m-3',
#  'diag_irga': 'adimensional',
#  'T_SONIC_corr': 'deg C',
#  'TA_1_1_1': 'deg C',
#  'PA': 'kPa',
#  'CO2_sig_strgth': 'fraction',
#  'H2O_sig_strgth': 'fraction'}

# %%
import matplotlib.pyplot as plt


df_imputed_pd['H2O_density'].plot()

# %%
def prepend_line(filename, line_to_prepend):
    with open(filename, 'r+', encoding='utf-8') as f:
        content = f.read()
        f.seek(0, 0)
        f.write(line_to_prepend.rstrip('\r\n') + '\n' + content)

# %%
# Load the data
config_path = f'../station_config/datafile.metadata'
# instantiate
config = ConfigParser()

# parse existing file
config.read(config_path)

fpath = pathlib.Path(r"C:\Users\paulinkenbrandt\Downloads\UGS Flux SDI12 Addresses Pakbus Metadata and Connection - Site_metadata.csv")
df = pd.read_csv(fpath)
df.dropna(subset=['stationid'], inplace=True)
df

for stat in df.index:
    site_id = df.loc[stat, 'stationid']
    name = df.loc[stat, 'parameter']
    latitude = df.loc[stat, 'latitude']
    longitude = df.loc[stat, 'longitude']
    altitude = df.loc[stat, 'altitude']
    canopy_height = df.loc[stat, 'height_canopy']

    config.set('Station', 'station_name', f"{name}")
    config.set('Station', 'station_id', f"{site_id}")
    config.set('Site','site_name', f"{name}")
    config.set('Site','site_id', f"{site_id}")
    config.set('Site','altitude', f"{altitude}")
    config.set('Site','latitude', f"{latitude}")
    config.set('Site','longitude', f"{longitude}")    
    config.set('Site','canopy_height', f"{canopy_height}")
    config.set('Timing','acquisition_frequency', f"{int(meas_freq):0d}")
    config.set('Timing','file_duration', f"{int(minutes):0d}")

    config.set('Project','title', f"{name}_{int(minutes):2d}min_process")
    config.set('Project','id', f"{site_id.split("-")[-1]}")

    with open(f'../station_config/edpro_{site_id.split("-")[-1]}.metadata', 'w') as configfile:
        config.write(configfile)
    prepend_line(f'../station_config/edpro_{site_id.split("-")[-1]}.metadata', ";GHG_METADATA")
