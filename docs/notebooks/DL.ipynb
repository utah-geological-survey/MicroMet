# %% [markdown]
# This notebook was used to compile all of the available data from the Utah Flux Network stations.  It should only need to be used once, as other notebooks are used to comile the newer data.

# %% [markdown]
# # Import Relevant Libraries

# %% [markdown]
# ## Standard Libraries

# %%
import pandas as pd
import numpy as np
import os
import geopandas as gpd
import sys
import pathlib
import glob
import matplotlib.pyplot as plt
from urllib.parse import quote
from sqlalchemy import create_engine
import configparser
import re

import statsmodels.api as sm
#import pingouin as pg
import plotly.express as px
import plotly.express as px

# %% [markdown]
# ## Import Libraries

# %%
import matplotlib
import pandas
import pathlib
import sys

sys.path.append("../../../Micromet")
import micromet

# %matplotlib inline

import logging
logger = logging.getLogger(__name__)
logger.setLevel(logging.ERROR)
ch = logging.StreamHandler()
ch.setFormatter(
    logging.Formatter(
        fmt="%(levelname)s [%(asctime)s] %(name)s – %(message)s",
        datefmt="%Y-%m-%d %H:%M:%S",
    )
)
logger.addHandler(ch)
# Out:
# credentials needed

# %% [markdown]
# # Run Compilation

# %% [markdown]
# ## List Sites for Examination

# %% [markdown]
# ## Compile Eddy Data

# %% [markdown]
# Search folders, reformat table, and save csv files

# %%
site_folders = {'US-UTD':'Dugout_Ranch',
                'US-UTB':'BSF',
                'US-UTJ':'Bluff',
                'US-UTW':'Wellington',
                'US-UTE':'Escalante',
                'US-UTM':'Matheson',
                'US-UTP':'Phrag',
                'US-CdM':'Cedar_mesa',
                'US-UTV':'Desert_View_Myton',
                'US-UTN':'Juab',
                'US-UTG':'Green_River'
                }

comp_edd_df = {}

am = micromet.AmerifluxDataProcessor(config_path='../../data/reformatter_vars.yml',
                                     logger=logger)

for key, value in site_folders.items():

    print(key)
    raw_fold = pathlib.Path('G:/Shared drives/UGS_Flux/Data_Downloads/')
    pths = micromet.fix_all_in_parent(raw_fold)
    raw_data = am.raw_file_compile(raw_fold, value, search_str = "*Flux_AmeriFluxFormat*.dat")
    if raw_data is not None:
        am_data = micromet.Reformatter(config_path="../../data/reformatter_vars.yml",
                                       var_limits_csv= "../../data/extreme_values.csv",
                                       drop_soil=False,
                                       logger=logger,
                                       )
        am_df = am_data.prepare(raw_data)
        comp_edd_df[key] = am_df

        am_df.to_csv(f"../../station_data/{key}_HH_{am_df['TIMESTAMP_START'].values[0]:}_{am_df['TIMESTAMP_END'].values[-1]:}.csv")
# Out:
# US-UTD
# INFO [2025-04-29 06:26:50] __main__ – Compiling data from G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch
# INFO [2025-04-29 06:26:50] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\Dugout Ranch_Flux_AmeriFluxFormat.dat
# DEBUG [2025-04-29 06:26:50] __main__ – 9999 -> 9999
# DEBUG [2025-04-29 06:26:50] __main__ – Skip rows for set to [0, 1, 2, 3]
# DEBUG [2025-04-29 06:26:50] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\Dugout Ranch_Flux_AmeriFluxFormat.dat
# INFO [2025-04-29 06:26:50] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20240415\21314_Flux_AmeriFluxFormat_4.dat
# DEBUG [2025-04-29 06:26:50] __main__ – 4 -> 21314
# DEBUG [2025-04-29 06:26:50] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'TA_1_1_4', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:26:50] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:26:50] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20240415\21314_Flux_AmeriFluxFormat_4.dat
# INFO [2025-04-29 06:26:50] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20240415\21314_Flux_AmeriFluxFormat_5.dat
# DEBUG [2025-04-29 06:26:50] __main__ – 5 -> 21314
# DEBUG [2025-04-29 06:26:50] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'TA_1_1_4', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:26:50] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:26:50] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20240415\21314_Flux_AmeriFluxFormat_5.dat
# INFO [2025-04-29 06:26:50] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20240415\21314_Flux_AmeriFluxFormat_6.dat
# DEBUG [2025-04-29 06:26:50] __main__ – 6 -> 21314
# DEBUG [2025-04-29 06:26:50] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'TA_1_1_4', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:26:50] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:26:50] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20240415\21314_Flux_AmeriFluxFormat_6.dat
# ✔ All possible files have been checked.
# INFO [2025-04-29 06:26:50] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20240415\21314_Flux_AmeriFluxFormat_7.dat
# DEBUG [2025-04-29 06:26:50] __main__ – 7 -> 21314
# DEBUG [2025-04-29 06:26:51] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'TA_1_1_4', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:26:51] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:26:51] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20240415\21314_Flux_AmeriFluxFormat_7.dat
# INFO [2025-04-29 06:26:51] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20240415\21314_Flux_AmeriFluxFormat_8.dat
# DEBUG [2025-04-29 06:26:51] __main__ – 8 -> 21314
# DEBUG [2025-04-29 06:26:51] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'TA_1_1_4', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:26:51] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:26:51] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20240415\21314_Flux_AmeriFluxFormat_8.dat
# INFO [2025-04-29 06:26:51] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20240415\21314_Flux_AmeriFluxFormat_9.dat
# DEBUG [2025-04-29 06:26:51] __main__ – 9 -> 21314
# DEBUG [2025-04-29 06:26:51] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'TA_1_1_4', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:26:51] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:26:51] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20240415\21314_Flux_AmeriFluxFormat_9.dat
# INFO [2025-04-29 06:26:51] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20240415\21314_Flux_AmeriFluxFormat_10.dat
# DEBUG [2025-04-29 06:26:51] __main__ – 10 -> 21314
# DEBUG [2025-04-29 06:26:51] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'TA_1_1_4', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:26:51] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:26:51] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20240415\21314_Flux_AmeriFluxFormat_10.dat
# INFO [2025-04-29 06:26:51] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20240415\21314_Flux_AmeriFluxFormat_3.dat
# DEBUG [2025-04-29 06:26:51] __main__ – 3 -> 21314
# DEBUG [2025-04-29 06:26:51] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'TA_1_1_4', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:26:51] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:26:51] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20240415\21314_Flux_AmeriFluxFormat_3.dat
# INFO [2025-04-29 06:26:51] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20240626\21314_Flux_AmeriFluxFormat_12.dat
# DEBUG [2025-04-29 06:26:51] __main__ – 12 -> 21314
# DEBUG [2025-04-29 06:26:51] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'TA_1_1_4', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:26:51] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:26:51] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20240626\21314_Flux_AmeriFluxFormat_12.dat
# INFO [2025-04-29 06:26:51] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20230723\21314_Flux_AmeriFluxFormat_0.dat
# DEBUG [2025-04-29 06:26:51] __main__ – 0 -> 21314
# DEBUG [2025-04-29 06:26:51] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'TA_1_1_4', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:26:51] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:26:51] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20230723\21314_Flux_AmeriFluxFormat_0.dat
# INFO [2025-04-29 06:26:51] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20230719\21314_Flux_AmeriFluxFormat_0.dat
# DEBUG [2025-04-29 06:26:51] __main__ – 0 -> 21314
# DEBUG [2025-04-29 06:26:51] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'TA_1_1_4', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:26:51] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:26:51] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20230719\21314_Flux_AmeriFluxFormat_0.dat
# INFO [2025-04-29 06:26:51] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20230719\21314_Flux_AmeriFluxFormat_1.dat
# DEBUG [2025-04-29 06:26:51] __main__ – 1 -> 21314
# DEBUG [2025-04-29 06:26:51] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'TA_1_1_4', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:26:51] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:26:51] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20230719\21314_Flux_AmeriFluxFormat_1.dat
# INFO [2025-04-29 06:26:51] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20230719\21314_Flux_AmeriFluxFormat_2.dat
# DEBUG [2025-04-29 06:26:51] __main__ – 2 -> 21314
# DEBUG [2025-04-29 06:26:51] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'TA_1_1_4', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:26:51] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:26:51] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20230719\21314_Flux_AmeriFluxFormat_2.dat
# INFO [2025-04-29 06:26:51] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20240822\21314_Flux_AmeriFluxFormat_12.dat
# DEBUG [2025-04-29 06:26:51] __main__ – 12 -> 21314
# DEBUG [2025-04-29 06:26:51] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'TA_1_1_4', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:26:51] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:26:51] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20240822\21314_Flux_AmeriFluxFormat_12.dat
# INFO [2025-04-29 06:26:51] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20240822\21314_Flux_AmeriFluxFormat_13.dat
# DEBUG [2025-04-29 06:26:51] __main__ – 13 -> 21314
# DEBUG [2025-04-29 06:26:51] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'TA_1_1_4', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:26:51] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:26:51] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20240822\21314_Flux_AmeriFluxFormat_13.dat
# INFO [2025-04-29 06:26:51] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20240822\21314_Flux_AmeriFluxFormat_14.dat
# DEBUG [2025-04-29 06:26:51] __main__ – 14 -> 21314
# DEBUG [2025-04-29 06:26:51] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'TA_1_1_4', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:26:51] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:26:51] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20240822\21314_Flux_AmeriFluxFormat_14.dat
# INFO [2025-04-29 06:26:51] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20240604\21314_Flux_AmeriFluxFormat_10.dat
# DEBUG [2025-04-29 06:26:51] __main__ – 10 -> 21314
# DEBUG [2025-04-29 06:26:51] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'TA_1_1_4', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:26:51] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:26:51] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20240604\21314_Flux_AmeriFluxFormat_10.dat
# INFO [2025-04-29 06:26:51] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20240604\21314_Flux_AmeriFluxFormat_11.dat
# DEBUG [2025-04-29 06:26:51] __main__ – 11 -> 21314
# DEBUG [2025-04-29 06:26:51] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'TA_1_1_4', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:26:51] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:26:51] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20240604\21314_Flux_AmeriFluxFormat_11.dat
# INFO [2025-04-29 06:26:51] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20240604\21314_Flux_AmeriFluxFormat_12.dat
# DEBUG [2025-04-29 06:26:51] __main__ – 12 -> 21314
# DEBUG [2025-04-29 06:26:51] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'TA_1_1_4', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:26:51] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:26:51] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20240604\21314_Flux_AmeriFluxFormat_12.dat
# INFO [2025-04-29 06:26:51] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20241009\21314_Flux_AmeriFluxFormat_14.dat
# DEBUG [2025-04-29 06:26:51] __main__ – 14 -> 21314
# DEBUG [2025-04-29 06:26:51] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'TA_1_1_4', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:26:51] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:26:51] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20241009\21314_Flux_AmeriFluxFormat_14.dat
# INFO [2025-04-29 06:26:51] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20241009\21314_Flux_AmeriFluxFormat_15.dat
# DEBUG [2025-04-29 06:26:51] __main__ – 15 -> 21314
# DEBUG [2025-04-29 06:26:51] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'TA_1_1_4', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:26:51] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:26:51] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20241009\21314_Flux_AmeriFluxFormat_15.dat
# INFO [2025-04-29 06:26:51] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20241009\21314_Flux_AmeriFluxFormat_16.dat
# DEBUG [2025-04-29 06:26:51] __main__ – 16 -> 21314
# DEBUG [2025-04-29 06:26:51] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'TA_1_1_4', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:26:51] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:26:51] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20241009\21314_Flux_AmeriFluxFormat_16.dat
# INFO [2025-04-29 06:26:51] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20250310\21314_Flux_AmeriFluxFormat_16.dat
# DEBUG [2025-04-29 06:26:51] __main__ – 16 -> 21314
# DEBUG [2025-04-29 06:26:51] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'TA_1_1_4', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:26:51] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:26:51] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20250310\21314_Flux_AmeriFluxFormat_16.dat
# INFO [2025-04-29 06:26:51] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20250310\21314_Flux_AmeriFluxFormat_17.dat
# DEBUG [2025-04-29 06:26:51] __main__ – 17 -> 21314
# DEBUG [2025-04-29 06:26:51] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'TA_1_1_4', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:26:51] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:26:51] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20250310\21314_Flux_AmeriFluxFormat_17.dat
# INFO [2025-04-29 06:26:51] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20250310\21314_Flux_AmeriFluxFormat_18.dat
# DEBUG [2025-04-29 06:26:51] __main__ – 18 -> 21314
# DEBUG [2025-04-29 06:26:51] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'TA_1_1_4', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:26:51] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:26:51] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20250310\21314_Flux_AmeriFluxFormat_18.dat
# INFO [2025-04-29 06:26:51] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20250310\21314_Flux_AmeriFluxFormat_19.dat
# DEBUG [2025-04-29 06:26:51] __main__ – 19 -> 21314
# DEBUG [2025-04-29 06:26:51] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'TA_1_1_4', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:26:51] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:26:51] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20250310\21314_Flux_AmeriFluxFormat_19.dat
# INFO [2025-04-29 06:26:51] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20250310\21314_Flux_AmeriFluxFormat_20.dat
# DEBUG [2025-04-29 06:26:51] __main__ – 20 -> 21314
# DEBUG [2025-04-29 06:26:51] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'TA_1_1_4', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:26:51] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:26:51] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20250310\21314_Flux_AmeriFluxFormat_20.dat
# INFO [2025-04-29 06:26:52] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20250310\21314_Flux_AmeriFluxFormat_21.dat
# DEBUG [2025-04-29 06:26:52] __main__ – 21 -> 21314
# DEBUG [2025-04-29 06:26:52] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'TA_1_1_4', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:26:52] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:26:52] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Dugout_Ranch\e20250310\21314_Flux_AmeriFluxFormat_21.dat
# INFO [2025-04-29 06:26:52] __main__ – Starting reformat (25736 rows)
# DEBUG [2025-04-29 06:26:52] __main__ – TS col TIMESTAMP_START
# DEBUG [2025-04-29 06:26:52] __main__ – TIMESTAMP_START col 202310111030
# DEBUG [2025-04-29 06:26:52] __main__ – Len of unfixed timestamps 25736
# DEBUG [2025-04-29 06:26:52] __main__ – Len of fixed timestamps 25708
# DEBUG [2025-04-29 06:26:52] __main__ – Len of normalized prefix cols 25708
# DEBUG [2025-04-29 06:26:52] __main__ – Len of renamed cols 25708
# DEBUG [2025-04-29 06:26:53] __main__ – Len of resampled timestamps 31492
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column CO2_SIGMA limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column P limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column SW_IN limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column LW_IN limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column SG limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column FETCH_MAX limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column WD limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column H2O limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column PBLH limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column USTAR limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column H2O_SIGMA limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column TAU limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column H_SSITC_TEST limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column SW_OUT limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column CO2 limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column T_SONIC limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column MO_LENGTH limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column LE_SSITC_TEST limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column VPD limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column FC_SSITC_TEST limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column G limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column T_SONIC_SIGMA limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column LE limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column WS_MAX limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column U_SIGMA limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column FC limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column NETRAD limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column H limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column ALB limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column ZL limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column FETCH_90 limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column LW_OUT limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column W_SIGMA limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column WS limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column V_SIGMA limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column TAU_SSITC_TEST limits
# DEBUG [2025-04-29 06:26:54] __main__ – Examining column PA limits
# DEBUG [2025-04-29 06:26:54] __main__ – Cleaned rows: 31492
# DEBUG [2025-04-29 06:26:54] __main__ – Scaled SSITC FC_SSITC_TEST
# DEBUG [2025-04-29 06:26:54] __main__ – Scaled SSITC LE_SSITC_TEST
# DEBUG [2025-04-29 06:26:54] __main__ – Scaled SSITC ET_SSITC_TEST
# DEBUG [2025-04-29 06:26:54] __main__ – Scaled SSITC H_SSITC_TEST
# DEBUG [2025-04-29 06:26:54] __main__ – Scaled SSITC TAU_SSITC_TEST
# DEBUG [2025-04-29 06:26:54] __main__ – Scaled SSITC len: 31492
# INFO [2025-04-29 06:26:54] __main__ – Done; final shape: (31492, 62)
# US-UTB
# INFO [2025-04-29 06:27:05] __main__ – Compiling data from G:\Shared drives\UGS_Flux\Data_Downloads\BSF
# INFO [2025-04-29 06:27:05] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\BSF\27736_Flux_AmeriFluxFormat_26.dat
# DEBUG [2025-04-29 06:27:05] __main__ – 26 -> 27736
# DEBUG [2025-04-29 06:27:05] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'SWC_1_1_1', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:27:05] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:27:05] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\BSF\27736_Flux_AmeriFluxFormat_26.dat
# ✔ All possible files have been checked.
# INFO [2025-04-29 06:27:05] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\BSF\27736_Flux_AmeriFluxFormat_27.dat
# DEBUG [2025-04-29 06:27:05] __main__ – 27 -> 27736
# DEBUG [2025-04-29 06:27:05] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'SWC_1_1_1', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:27:05] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:27:05] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\BSF\27736_Flux_AmeriFluxFormat_27.dat
# INFO [2025-04-29 06:27:05] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\BSF\27736_Flux_AmeriFluxFormat_28.dat
# DEBUG [2025-04-29 06:27:05] __main__ – 28 -> 27736
# DEBUG [2025-04-29 06:27:05] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'SWC_1_1_1', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:27:05] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:27:05] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\BSF\27736_Flux_AmeriFluxFormat_28.dat
# INFO [2025-04-29 06:27:05] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\BSF\27736_Flux_AmeriFluxFormat_29.dat
# DEBUG [2025-04-29 06:27:05] __main__ – 29 -> 27736
# DEBUG [2025-04-29 06:27:05] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'SWC_1_1_1', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:27:05] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:27:05] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\BSF\27736_Flux_AmeriFluxFormat_29.dat
# INFO [2025-04-29 06:27:05] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\BSF\27736_Flux_AmeriFluxFormat_25.dat
# DEBUG [2025-04-29 06:27:05] __main__ – 25 -> 27736
# DEBUG [2025-04-29 06:27:05] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'SWC_1_1_1', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:27:05] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:27:05] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\BSF\27736_Flux_AmeriFluxFormat_25.dat
# INFO [2025-04-29 06:27:05] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\BSF\27736_Flux_AmeriFluxFormat_5.dat
# DEBUG [2025-04-29 06:27:05] __main__ – 5 -> 27736
# DEBUG [2025-04-29 06:27:05] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'SWC_1_1_1', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:27:05] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:27:05] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\BSF\27736_Flux_AmeriFluxFormat_5.dat
# INFO [2025-04-29 06:27:05] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\BSF\27736_Flux_AmeriFluxFormat_6.dat
# DEBUG [2025-04-29 06:27:05] __main__ – 6 -> 27736
# DEBUG [2025-04-29 06:27:05] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'SWC_1_1_1', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:27:05] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:27:05] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\BSF\27736_Flux_AmeriFluxFormat_6.dat
# INFO [2025-04-29 06:27:06] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\BSF\27736_Flux_AmeriFluxFormat_7.dat
# DEBUG [2025-04-29 06:27:06] __main__ – 7 -> 27736
# DEBUG [2025-04-29 06:27:06] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'SWC_1_1_1', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:27:06] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:27:06] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\BSF\27736_Flux_AmeriFluxFormat_7.dat
# INFO [2025-04-29 06:27:06] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\BSF\27736_Flux_AmeriFluxFormat_8.dat
# DEBUG [2025-04-29 06:27:06] __main__ – 8 -> 27736
# DEBUG [2025-04-29 06:27:06] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'SWC_1_1_1', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:27:06] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:27:06] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\BSF\27736_Flux_AmeriFluxFormat_8.dat
# INFO [2025-04-29 06:27:06] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\BSF\27736_Flux_AmeriFluxFormat_10.dat
# DEBUG [2025-04-29 06:27:06] __main__ – 10 -> 27736
# DEBUG [2025-04-29 06:27:06] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'SWC_1_1_1', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:27:06] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:27:06] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\BSF\27736_Flux_AmeriFluxFormat_10.dat
# INFO [2025-04-29 06:27:06] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\BSF\27736_Flux_AmeriFluxFormat_9.dat
# DEBUG [2025-04-29 06:27:06] __main__ – 9 -> 27736
# DEBUG [2025-04-29 06:27:06] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'SWC_1_1_1', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:27:06] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:27:06] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\BSF\27736_Flux_AmeriFluxFormat_9.dat
# INFO [2025-04-29 06:27:06] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\BSF\27736_Flux_AmeriFluxFormat_12.dat
# DEBUG [2025-04-29 06:27:06] __main__ – 12 -> 27736
# DEBUG [2025-04-29 06:27:06] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'SWC_1_1_1', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-04-29 06:27:06] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:27:06] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\BSF\27736_Flux_AmeriFluxFormat_12.dat
# INFO [2025-04-29 06:27:06] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\BSF\27736_Flux_AmeriFluxFormat_11.dat
# DEBUG [2025-04-29 06:27:06] __main__ – 11 -> 27736
# ...
# DEBUG [2025-04-29 06:29:40] __main__ – 442 -> 21022
# DEBUG [2025-04-29 06:29:40] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_2_1', 'RH_1_2_1', 'T_DP_1_1_2', 'TA_1_3_1', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'SWC_3_1_1', 'SWC_4_1_1', 'K_3_1_1', 'TS_3_1_1', 'EC_3_1_1', 'SWC_3_2_1', 'K_3_2_1', 'TS_3_2_1', 'EC_3_2_1', 'SWC_3_3_1', 'K_3_3_1', 'TS_3_3_1', 'BulkEC_20cm_N_Avg', 'SWC_3_4_1', 'K_3_4_1', 'TS_3_4_1', 'EC_3_4_1', 'SWC_3_5_1', 'K_3_5_1', 'TS_3_5_1', 'EC_3_5_1', 'SWC_3_6_1', 'K_3_6_1', 'TS_3_6_1', 'EC_3_6_1', 'SWC_3_7_1', 'K_3_7_1', 'TS_3_7_1', 'EC_3_7_1', 'SWC_3_8_1', 'K_3_8_1', 'TS_3_8_1', 'EC_3_8_1', 'SWC_3_9_1', 'K_3_9_1', 'TS_3_9_1', 'EC_3_9_1', 'K_4_1_1', 'TS_4_1_1', 'EC_4_1_1', 'SWC_4_2_1', 'K_4_2_1', 'TS_4_2_1', 'EC_4_2_1', 'SWC_4_3_1', 'K_4_3_1', 'TS_4_3_1', 'EC_4_3_1', 'SWC_4_4_1', 'K_4_4_1', 'TS_4_4_1', 'EC_4_4_1', 'SWC_4_5_1', 'K_4_5_1', 'TS_4_5_1', 'EC_4_5_1', 'SWC_4_6_1', 'K_4_6_1', 'TS_4_6_1', 'EC_4_6_1', 'SWC_4_7_1', 'K_4_7_1', 'TS_4_7_1', 'EC_4_7_1', 'SWC_4_8_1', 'K_4_8_1', 'TS_4_8_1', 'EC_4_8_1', 'EC_4_9_1', 'SWC_4_9_1', 'K_4_9_1', 'TS_4_9_1', 'TS_1_1_1', 'TS_2_1_1', 'SWC_1_1_1', 'SWC_2_1_1', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P', 'T_CANOPY']
# DEBUG [2025-04-29 06:29:40] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:29:40] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Matheson\e20250127\21022_Flux_AmeriFluxFormat_442.dat
# INFO [2025-04-29 06:29:40] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Matheson\e20250127\21022_Flux_AmeriFluxFormat_44.dat
# DEBUG [2025-04-29 06:29:40] __main__ – 44 -> 21022
# DEBUG [2025-04-29 06:29:40] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_2_1', 'RH_1_2_1', 'T_DP_1_1_2', 'TA_1_3_1', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'SWC_3_1_1', 'SWC_4_1_1', 'K_3_1_1', 'TS_3_1_1', 'EC_3_1_1', 'SWC_3_2_1', 'K_3_2_1', 'TS_3_2_1', 'EC_3_2_1', 'SWC_3_3_1', 'K_3_3_1', 'TS_3_3_1', 'BulkEC_20cm_N_Avg', 'SWC_3_4_1', 'K_3_4_1', 'TS_3_4_1', 'EC_3_4_1', 'SWC_3_5_1', 'K_3_5_1', 'TS_3_5_1', 'EC_3_5_1', 'SWC_3_6_1', 'K_3_6_1', 'TS_3_6_1', 'EC_3_6_1', 'SWC_3_7_1', 'K_3_7_1', 'TS_3_7_1', 'EC_3_7_1', 'SWC_3_8_1', 'K_3_8_1', 'TS_3_8_1', 'EC_3_8_1', 'SWC_3_9_1', 'K_3_9_1', 'TS_3_9_1', 'EC_3_9_1', 'K_4_1_1', 'TS_4_1_1', 'EC_4_1_1', 'SWC_4_2_1', 'K_4_2_1', 'TS_4_2_1', 'EC_4_2_1', 'SWC_4_3_1', 'K_4_3_1', 'TS_4_3_1', 'EC_4_3_1', 'SWC_4_4_1', 'K_4_4_1', 'TS_4_4_1', 'EC_4_4_1', 'SWC_4_5_1', 'K_4_5_1', 'TS_4_5_1', 'EC_4_5_1', 'SWC_4_6_1', 'K_4_6_1', 'TS_4_6_1', 'EC_4_6_1', 'SWC_4_7_1', 'K_4_7_1', 'TS_4_7_1', 'EC_4_7_1', 'SWC_4_8_1', 'K_4_8_1', 'TS_4_8_1', 'EC_4_8_1', 'EC_4_9_1', 'SWC_4_9_1', 'K_4_9_1', 'TS_4_9_1', 'TS_1_1_1', 'TS_2_1_1', 'SWC_1_1_1', 'SWC_2_1_1', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P', 'T_CANOPY']
# DEBUG [2025-04-29 06:29:40] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:29:40] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Matheson\e20250127\21022_Flux_AmeriFluxFormat_44.dat
# INFO [2025-04-29 06:29:40] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Matheson\e20250127\21022_Flux_AmeriFluxFormat_445.dat
# DEBUG [2025-04-29 06:29:40] __main__ – 445 -> 21022
# DEBUG [2025-04-29 06:29:40] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_2_1', 'RH_1_2_1', 'T_DP_1_1_2', 'TA_1_3_1', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'SWC_3_1_1', 'SWC_4_1_1', 'K_3_1_1', 'TS_3_1_1', 'EC_3_1_1', 'SWC_3_2_1', 'K_3_2_1', 'TS_3_2_1', 'EC_3_2_1', 'SWC_3_3_1', 'K_3_3_1', 'TS_3_3_1', 'BulkEC_20cm_N_Avg', 'SWC_3_4_1', 'K_3_4_1', 'TS_3_4_1', 'EC_3_4_1', 'SWC_3_5_1', 'K_3_5_1', 'TS_3_5_1', 'EC_3_5_1', 'SWC_3_6_1', 'K_3_6_1', 'TS_3_6_1', 'EC_3_6_1', 'SWC_3_7_1', 'K_3_7_1', 'TS_3_7_1', 'EC_3_7_1', 'SWC_3_8_1', 'K_3_8_1', 'TS_3_8_1', 'EC_3_8_1', 'SWC_3_9_1', 'K_3_9_1', 'TS_3_9_1', 'EC_3_9_1', 'K_4_1_1', 'TS_4_1_1', 'EC_4_1_1', 'SWC_4_2_1', 'K_4_2_1', 'TS_4_2_1', 'EC_4_2_1', 'SWC_4_3_1', 'K_4_3_1', 'TS_4_3_1', 'EC_4_3_1', 'SWC_4_4_1', 'K_4_4_1', 'TS_4_4_1', 'EC_4_4_1', 'SWC_4_5_1', 'K_4_5_1', 'TS_4_5_1', 'EC_4_5_1', 'SWC_4_6_1', 'K_4_6_1', 'TS_4_6_1', 'EC_4_6_1', 'SWC_4_7_1', 'K_4_7_1', 'TS_4_7_1', 'EC_4_7_1', 'SWC_4_8_1', 'K_4_8_1', 'TS_4_8_1', 'EC_4_8_1', 'EC_4_9_1', 'SWC_4_9_1', 'K_4_9_1', 'TS_4_9_1', 'TS_1_1_1', 'TS_2_1_1', 'SWC_1_1_1', 'SWC_2_1_1', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P', 'T_CANOPY']
# DEBUG [2025-04-29 06:29:40] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:29:40] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Matheson\e20250127\21022_Flux_AmeriFluxFormat_445.dat
# INFO [2025-04-29 06:29:40] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Matheson\e20250127\21022_Flux_AmeriFluxFormat_440.dat
# DEBUG [2025-04-29 06:29:40] __main__ – 440 -> 21022
# DEBUG [2025-04-29 06:29:40] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_2_1', 'RH_1_2_1', 'T_DP_1_1_2', 'TA_1_3_1', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'SWC_3_1_1', 'SWC_4_1_1', 'K_3_1_1', 'TS_3_1_1', 'EC_3_1_1', 'SWC_3_2_1', 'K_3_2_1', 'TS_3_2_1', 'EC_3_2_1', 'SWC_3_3_1', 'K_3_3_1', 'TS_3_3_1', 'BulkEC_20cm_N_Avg', 'SWC_3_4_1', 'K_3_4_1', 'TS_3_4_1', 'EC_3_4_1', 'SWC_3_5_1', 'K_3_5_1', 'TS_3_5_1', 'EC_3_5_1', 'SWC_3_6_1', 'K_3_6_1', 'TS_3_6_1', 'EC_3_6_1', 'SWC_3_7_1', 'K_3_7_1', 'TS_3_7_1', 'EC_3_7_1', 'SWC_3_8_1', 'K_3_8_1', 'TS_3_8_1', 'EC_3_8_1', 'SWC_3_9_1', 'K_3_9_1', 'TS_3_9_1', 'EC_3_9_1', 'K_4_1_1', 'TS_4_1_1', 'EC_4_1_1', 'SWC_4_2_1', 'K_4_2_1', 'TS_4_2_1', 'EC_4_2_1', 'SWC_4_3_1', 'K_4_3_1', 'TS_4_3_1', 'EC_4_3_1', 'SWC_4_4_1', 'K_4_4_1', 'TS_4_4_1', 'EC_4_4_1', 'SWC_4_5_1', 'K_4_5_1', 'TS_4_5_1', 'EC_4_5_1', 'SWC_4_6_1', 'K_4_6_1', 'TS_4_6_1', 'EC_4_6_1', 'SWC_4_7_1', 'K_4_7_1', 'TS_4_7_1', 'EC_4_7_1', 'SWC_4_8_1', 'K_4_8_1', 'TS_4_8_1', 'EC_4_8_1', 'EC_4_9_1', 'SWC_4_9_1', 'K_4_9_1', 'TS_4_9_1', 'TS_1_1_1', 'TS_2_1_1', 'SWC_1_1_1', 'SWC_2_1_1', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P', 'T_CANOPY']
# DEBUG [2025-04-29 06:29:40] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:29:40] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Matheson\e20250127\21022_Flux_AmeriFluxFormat_440.dat
# INFO [2025-04-29 06:29:40] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Matheson\e20250127\21022_Flux_AmeriFluxFormat_447.dat
# DEBUG [2025-04-29 06:29:40] __main__ – 447 -> 21022
# DEBUG [2025-04-29 06:29:40] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_2_1', 'RH_1_2_1', 'T_DP_1_1_2', 'TA_1_3_1', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'SWC_3_1_1', 'SWC_4_1_1', 'K_3_1_1', 'TS_3_1_1', 'EC_3_1_1', 'SWC_3_2_1', 'K_3_2_1', 'TS_3_2_1', 'EC_3_2_1', 'SWC_3_3_1', 'K_3_3_1', 'TS_3_3_1', 'BulkEC_20cm_N_Avg', 'SWC_3_4_1', 'K_3_4_1', 'TS_3_4_1', 'EC_3_4_1', 'SWC_3_5_1', 'K_3_5_1', 'TS_3_5_1', 'EC_3_5_1', 'SWC_3_6_1', 'K_3_6_1', 'TS_3_6_1', 'EC_3_6_1', 'SWC_3_7_1', 'K_3_7_1', 'TS_3_7_1', 'EC_3_7_1', 'SWC_3_8_1', 'K_3_8_1', 'TS_3_8_1', 'EC_3_8_1', 'SWC_3_9_1', 'K_3_9_1', 'TS_3_9_1', 'EC_3_9_1', 'K_4_1_1', 'TS_4_1_1', 'EC_4_1_1', 'SWC_4_2_1', 'K_4_2_1', 'TS_4_2_1', 'EC_4_2_1', 'SWC_4_3_1', 'K_4_3_1', 'TS_4_3_1', 'EC_4_3_1', 'SWC_4_4_1', 'K_4_4_1', 'TS_4_4_1', 'EC_4_4_1', 'SWC_4_5_1', 'K_4_5_1', 'TS_4_5_1', 'EC_4_5_1', 'SWC_4_6_1', 'K_4_6_1', 'TS_4_6_1', 'EC_4_6_1', 'SWC_4_7_1', 'K_4_7_1', 'TS_4_7_1', 'EC_4_7_1', 'SWC_4_8_1', 'K_4_8_1', 'TS_4_8_1', 'EC_4_8_1', 'EC_4_9_1', 'SWC_4_9_1', 'K_4_9_1', 'TS_4_9_1', 'TS_1_1_1', 'TS_2_1_1', 'SWC_1_1_1', 'SWC_2_1_1', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P', 'T_CANOPY']
# DEBUG [2025-04-29 06:29:40] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:29:40] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Matheson\e20250127\21022_Flux_AmeriFluxFormat_447.dat
# INFO [2025-04-29 06:29:40] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Matheson\e20250127\21022_Flux_AmeriFluxFormat_461.dat
# DEBUG [2025-04-29 06:29:40] __main__ – 461 -> 21022
# DEBUG [2025-04-29 06:29:40] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_2_1', 'RH_1_2_1', 'T_DP_1_1_2', 'TA_1_3_1', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'SWC_3_1_1', 'SWC_4_1_1', 'K_3_1_1', 'TS_3_1_1', 'EC_3_1_1', 'SWC_3_2_1', 'K_3_2_1', 'TS_3_2_1', 'EC_3_2_1', 'SWC_3_3_1', 'K_3_3_1', 'TS_3_3_1', 'BulkEC_20cm_N_Avg', 'SWC_3_4_1', 'K_3_4_1', 'TS_3_4_1', 'EC_3_4_1', 'SWC_3_5_1', 'K_3_5_1', 'TS_3_5_1', 'EC_3_5_1', 'SWC_3_6_1', 'K_3_6_1', 'TS_3_6_1', 'EC_3_6_1', 'SWC_3_7_1', 'K_3_7_1', 'TS_3_7_1', 'EC_3_7_1', 'SWC_3_8_1', 'K_3_8_1', 'TS_3_8_1', 'EC_3_8_1', 'SWC_3_9_1', 'K_3_9_1', 'TS_3_9_1', 'EC_3_9_1', 'K_4_1_1', 'TS_4_1_1', 'EC_4_1_1', 'SWC_4_2_1', 'K_4_2_1', 'TS_4_2_1', 'EC_4_2_1', 'SWC_4_3_1', 'K_4_3_1', 'TS_4_3_1', 'EC_4_3_1', 'SWC_4_4_1', 'K_4_4_1', 'TS_4_4_1', 'EC_4_4_1', 'SWC_4_5_1', 'K_4_5_1', 'TS_4_5_1', 'EC_4_5_1', 'SWC_4_6_1', 'K_4_6_1', 'TS_4_6_1', 'EC_4_6_1', 'SWC_4_7_1', 'K_4_7_1', 'TS_4_7_1', 'EC_4_7_1', 'SWC_4_8_1', 'K_4_8_1', 'TS_4_8_1', 'EC_4_8_1', 'EC_4_9_1', 'SWC_4_9_1', 'K_4_9_1', 'TS_4_9_1', 'TS_1_1_1', 'TS_2_1_1', 'SWC_1_1_1', 'SWC_2_1_1', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P', 'T_CANOPY']
# DEBUG [2025-04-29 06:29:40] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:29:40] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Matheson\e20250127\21022_Flux_AmeriFluxFormat_461.dat
# INFO [2025-04-29 06:29:40] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Matheson\e20250127\21022_Flux_AmeriFluxFormat_460.dat
# DEBUG [2025-04-29 06:29:40] __main__ – 460 -> 21022
# DEBUG [2025-04-29 06:29:40] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_2_1', 'RH_1_2_1', 'T_DP_1_1_2', 'TA_1_3_1', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'SWC_3_1_1', 'SWC_4_1_1', 'K_3_1_1', 'TS_3_1_1', 'EC_3_1_1', 'SWC_3_2_1', 'K_3_2_1', 'TS_3_2_1', 'EC_3_2_1', 'SWC_3_3_1', 'K_3_3_1', 'TS_3_3_1', 'BulkEC_20cm_N_Avg', 'SWC_3_4_1', 'K_3_4_1', 'TS_3_4_1', 'EC_3_4_1', 'SWC_3_5_1', 'K_3_5_1', 'TS_3_5_1', 'EC_3_5_1', 'SWC_3_6_1', 'K_3_6_1', 'TS_3_6_1', 'EC_3_6_1', 'SWC_3_7_1', 'K_3_7_1', 'TS_3_7_1', 'EC_3_7_1', 'SWC_3_8_1', 'K_3_8_1', 'TS_3_8_1', 'EC_3_8_1', 'SWC_3_9_1', 'K_3_9_1', 'TS_3_9_1', 'EC_3_9_1', 'K_4_1_1', 'TS_4_1_1', 'EC_4_1_1', 'SWC_4_2_1', 'K_4_2_1', 'TS_4_2_1', 'EC_4_2_1', 'SWC_4_3_1', 'K_4_3_1', 'TS_4_3_1', 'EC_4_3_1', 'SWC_4_4_1', 'K_4_4_1', 'TS_4_4_1', 'EC_4_4_1', 'SWC_4_5_1', 'K_4_5_1', 'TS_4_5_1', 'EC_4_5_1', 'SWC_4_6_1', 'K_4_6_1', 'TS_4_6_1', 'EC_4_6_1', 'SWC_4_7_1', 'K_4_7_1', 'TS_4_7_1', 'EC_4_7_1', 'SWC_4_8_1', 'K_4_8_1', 'TS_4_8_1', 'EC_4_8_1', 'EC_4_9_1', 'SWC_4_9_1', 'K_4_9_1', 'TS_4_9_1', 'TS_1_1_1', 'TS_2_1_1', 'SWC_1_1_1', 'SWC_2_1_1', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P', 'T_CANOPY']
# DEBUG [2025-04-29 06:29:40] __main__ – Skip rows for set to 0
# DEBUG [2025-04-29 06:29:40] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Matheson\e20250127\21022_Flux_AmeriFluxFormat_460.dat
# INFO [2025-04-29 06:29:40] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Matheson\e20250127\21022_Flux_AmeriFluxFormat_449.dat
# DEBUG [2025-04-29 06:29:40] __main__ – 449 -> 21022
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 24
#      22 raw_fold = pathlib.Path('G:/Shared drives/UGS_Flux/Data_Downloads/')
#      23 pths = micromet.fix_all_in_parent(raw_fold)
# ---> 24 raw_data = am.raw_file_compile(raw_fold, value, search_str = "*Flux_AmeriFluxFormat*.dat")
#      25 if raw_data is not None:
#      26     am_data = micromet.Reformatter(config_path="../../data/reformatter_vars.yml",
#      27                                    var_limits_csv= "../../data/extreme_values.csv",
#      28                                    drop_soil=False,
#      29                                    logger=logger,
#      30                                    )
#
# File ~\Documents\GitHub\MicroMet\micromet\converter.py:174, in AmerifluxDataProcessor.raw_file_compile(self, main_dir, station_folder_name, search_str)
#     170 self.logger.info(f"Processing file: {file}")
#     172 file_no, datalogger_number = self._get_file_no(file)
# --> 174 df = self.to_dataframe(file)
#     175 if df is not None:
#     176     df["file_no"] = file_no
#
# File ~\Documents\GitHub\MicroMet\micromet\converter.py:93, in AmerifluxDataProcessor.to_dataframe(self, file)
#      91 def to_dataframe(self, file: Union[str, Path]) -> pd.DataFrame:
#      92     """Return parsed CSV as pandas DataFrame."""
# ---> 93     self._determine_header_rows(file)
#      94     self.logger.debug("Reading %s", file)
#      95     df = pd.read_csv(file,
#      96                      skiprows=self.skip_rows,
#      97                      names=self.names,
#      98                      na_values=self.NA_VALUES,
#      99                      )
#
# File ~\Documents\GitHub\MicroMet\micromet\converter.py:123, in AmerifluxDataProcessor._determine_header_rows(self, file)
#     121     self.names = second_line
#     122 else:
# --> 123     raise RuntimeError(f"Header line not recognized: {first_line}")
#     124 self.logger.debug(f"Skip rows for set to {self.skip_rows}")
#
# RuntimeError: Header line not recognized: ['Aäy²\x00\x00\x00\x00D\x1a@ÀD\x1cÄÍ@j']

# %% [markdown]
# Compile files from each station into a a single dataframe.

# %%
cdf = pd.concat(comp_edd_df, axis=0)
cdf.index.set_names(['stationid','datetime_start'],inplace=True)
#cdf.rename(columns={'level_0':'stationid'},inplace=True)
#cdf.to_parquet('../station_data/all_data.parquet')
for col in cdf.columns:
    cdf.rename(columns={col:col.lower()},inplace=True)

# %% [markdown]
# Save to Parquet

# %%
cdf.to_parquet('../../station_data/all_eddy_data.parquet')

# %%
comp_met_df = {}

am = micromet.AmerifluxDataProcessor()

for key, value in site_folders.items():

    print(key)
    raw_fold = pathlib.Path('G:/Shared drives/UGS_Flux/Data_Downloads/')
    raw_data = am.raw_file_compile(raw_fold, value, search_str = "*Statistics_AmeriFlux*.dat")
    if raw_data is not None:
        am_data = micromet.Reformatter(raw_data,
                                       config_path="../../data/reformatter_vars.yml", 
                                       drop_soil=False,
                                       data_type='met'
                                       )
        am_df = am_data.et_data
        comp_met_df[key] = am_df

        #am_df.to_csv(f"../../station_data/{key}_HH_{am_df['TIMESTAMP_START'].values[0]:}_{am_df['TIMESTAMP_END'].values[-1]:}.csv")

# %%
mapping = {
    "T_100cm_N_Avg": "TS_3_9_1",
    "BulkEC_5cm_N_Avg": "EC_3_1_1",
    "BulkEC_10cm_N_Avg": "EC_3_2_1",
    "BulkEC_20cm_N_Avg": "EC_3_3_1",
    "BulkEC_30cm_N_Avg": "EC_3_4_1",
    "BulkEC_40cm_N_Avg": "EC_3_5_1",
    "BulkEC_50cm_N_Avg": "EC_3_6_1",
    "BulkEC_60cm_N_Avg": "EC_3_7_1",
    "BulkEC_75cm_N_Avg": "EC_3_8_1",
    "BulkEC_100cm_N_Avg": "EC_3_9_1",
    "VWC_5cm_S_Avg": "SWC_4_1_1",
    "VWC_10cm_S_Avg": "SWC_4_2_1",
    "VWC_20cm_S_Avg": "SWC_4_3_1",
    "VWC_30cm_S_Avg": "SWC_4_4_1",
    "VWC_40cm_S_Avg": "SWC_4_5_1",
    "VWC_50cm_S_Avg": "SWC_4_6_1",
    "VWC_60cm_S_Avg": "SWC_4_7_1",
    "VWC_75cm_S_Avg": "SWC_4_8_1",
    "VWC_100cm_S_Avg": "SWC_4_9_1",
    "Ka_5cm_S_Avg": "K_4_1_1",
    "Ka_10cm_S_Avg": "K_4_2_1",
    "Ka_20cm_S_Avg": "K_4_3_1",
    "Ka_30cm_S_Avg": "K_4_4_1",
    "Ka_40cm_S_Avg": "K_4_5_1",
    "Ka_50cm_S_Avg": "K_4_6_1",
    "Ka_60cm_S_Avg": "K_4_7_1",
    "Ka_75cm_S_Avg": "K_4_8_1",
    "Ka_100cm_S_Avg": "K_4_9_1",
    "T_5cm_S_Avg": "TS_4_1_1",
    "T_10cm_S_Avg": "TS_4_2_1",
    "T_20cm_S_Avg": "TS_4_3_1",
    "T_30cm_S_Avg": "TS_4_4_1",
    "T_40cm_S_Avg": "TS_4_5_1",
    "T_50cm_S_Avg": "TS_4_6_1",
    "T_60cm_S_Avg": "TS_4_7_1",
    "T_75cm_S_Avg": "TS_4_8_1",
    "T_100cm_S_Avg": "TS_4_9_1",
    "BulkEC_5cm_S_Avg": "EC_4_1_1",
    "BulkEC_10cm_S_Avg": "EC_4_2_1",
    "BulkEC_20cm_S_Avg": "EC_4_3_1",
    "BulkEC_30cm_S_Avg": "EC_4_4_1",
    "BulkEC_40cm_S_Avg": "EC_4_5_1",
    "BulkEC_50cm_S_Avg": "EC_4_6_1",
    "BulkEC_60cm_S_Avg": "EC_4_7_1",
    "BulkEC_75cm_S_Avg": "EC_4_8_1",
    "BulkEC_100cm_S_Avg": "EC_4_9_1",
    "VWC_5cm_Avg": "SWC_3_1_1",
    "VWC_10cm_Avg": "SWC_3_2_1",
    "VWC_20cm_Avg": "SWC_3_3_1",
    "VWC_30cm_Avg": "SWC_3_4_1",
    "VWC_40cm_Avg": "SWC_3_5_1",
    "VWC_50cm_Avg": "SWC_3_6_1",
    "VWC_60cm_Avg": "SWC_3_7_1",
    "VWC_75cm_Avg": "SWC_3_8_1",
    "VWC_100cm_Avg": "SWC_3_9_1",
    "Ka_5cm_Avg": "K_3_1_1",
    "Ka_10cm_Avg": "K_3_2_1",
    "Ka_20cm_Avg": "K_3_3_1",
    "Ka_30cm_Avg": "K_3_4_1",
    "Ka_40cm_Avg": "K_3_5_1",
    "Ka_50cm_Avg": "K_3_6_1",
    "Ka_60cm_Avg": "K_3_7_1",
    "Ka_75cm_Avg": "K_3_8_1",
    "Ka_100cm_Avg": "K_3_9_1",
    "T_5cm_Avg": "TS_3_1_1",
    "T_10cm_Avg": "TS_3_2_1",
    "T_20cm_Avg": "TS_3_3_1",
    "T_30cm_Avg": "TS_3_4_1",
    "T_40cm_Avg": "TS_3_5_1",
    "T_50cm_Avg": "TS_3_6_1",
    "T_60cm_Avg": "TS_3_7_1",
    "T_75cm_Avg": "TS_3_8_1",
    "T_100cm_Avg": "TS_3_9_1",
    "BulkEC_5cm_Avg": "EC_3_1_1",
    "BulkEC_10cm_Avg": "EC_3_2_1",
    "BulkEC_20cm_Avg": "EC_3_3_1",
    "BulkEC_30cm_Avg": "EC_3_4_1",
    "BulkEC_40cm_Avg": "EC_3_5_1",
    "BulkEC_50cm_Avg": "EC_3_6_1",
    "BulkEC_60cm_Avg": "EC_3_7_1",
    "BulkEC_75cm_Avg": "EC_3_8_1",
    "BulkEC_100cm_Avg": "EC_3_9_1",
    "BulkEC_3_1_1": "EC_3_1_1",
    "BulkEC_3_2_1": "EC_3_2_1",
    "BulkEC_3_3_1": "EC_3_3_1",
    "BulkEC_3_4_1": "EC_3_4_1",
    "BulkEC_3_5_1": "EC_3_5_1",
    "BulkEC_3_6_1": "EC_3_6_1",
    "BulkEC_3_7_1": "EC_3_7_1",
    "BulkEC_3_8_1": "EC_3_8_1",
    "BulkEC_3_9_1": "EC_3_9_1",
    "KA_3_1_1": "K_3_1_1",
    "KA_3_2_1": "K_3_2_1",
    "KA_3_3_1": "K_3_3_1",
    "KA_3_4_1": "K_3_4_1",
    "KA_3_5_1": "K_3_5_1",
    "KA_3_6_1": "K_3_6_1",
    "KA_3_7_1": "K_3_7_1",
    "KA_3_8_1": "K_3_8_1",
    "KA_3_9_1": "K_3_9_1",
    "VWC_2_1_1": "SWC_3_1_1",
    "VWC_2_2_1": "SWC_3_2_1",
    "VWC_2_3_1": "SWC_3_3_1",
    "VWC_2_4_1": "SWC_3_4_1",
    "VWC_2_5_1": "SWC_3_5_1",
    "VWC_2_6_1": "SWC_3_6_1",
    "VWC_2_7_1": "SWC_3_7_1",
    "VWC_2_8_1": "SWC_3_8_1",
    "VWC_2_9_1": "SWC_3_9_1",
    "VWC_3_1_1": "SWC_4_1_1",
    "VWC_3_2_1": "SWC_4_2_1",
    "VWC_3_3_1": "SWC_4_3_1",
    "VWC_3_4_1": "SWC_4_4_1",
    "VWC_3_5_1": "SWC_4_5_1",
    "VWC_3_6_1": "SWC_4_6_1",
    "VWC_3_7_1": "SWC_4_7_1",
    "VWC_3_8_1": "SWC_4_8_1",
    "VWC_3_9_1": "SWC_4_9_1",
    "T__1_8_1": "TS_3_8_1",
    "KA_4_1_1": "K_4_1_1",
    "KA_4_2_1": "K_4_2_1",
    "KA_4_3_1": "K_4_3_1",
    "KA_4_4_1": "K_4_4_1",
    "KA_4_5_1": "K_4_5_1",
    "KA_4_6_1": "K_4_6_1",
    "KA_4_7_1": "K_4_7_1",
    "KA_4_8_1": "K_4_8_1",
    "KA_4_9_1": "K_4_9_1",
    "BulkEC_4_1_1": "EC_4_1_1",
    "BulkEC_4_2_1": "EC_4_2_1",
    "BulkEC_4_3_1": "EC_4_3_1",
    "BulkEC_4_4_1": "EC_4_4_1",
    "BulkEC_4_5_1": "EC_4_5_1",
    "BulkEC_4_6_1": "EC_4_6_1",
    "BulkEC_4_7_1": "EC_4_7_1",
    "BulkEC_4_8_1": "EC_4_8_1",
    "BulkEC_4_9_1": "EC_4_9_1",
    "KA_2_1_1": "K_4_1_1",
    "KA_2_2_1": "K_4_2_1",
    "KA_2_3_1": "K_4_3_1",
    "KA_2_4_1": "K_4_4_1",
    "KA_2_5_1": "K_4_5_1",
    "KA_2_6_1": "K_4_6_1",
    "KA_2_7_1": "K_4_7_1",
    "KA_2_8_1": "K_4_8_1",
    "KA_2_9_1": "K_4_9_1",
    "BulkEC_2_1_1": "EC_4_1_1",
    "BulkEC_2_2_1": "EC_4_2_1",
    "BulkEC_2_3_1": "EC_4_3_1",
    "BulkEC_2_4_1": "EC_4_4_1",
    "BulkEC_2_5_1": "EC_4_5_1",
    "BulkEC_2_6_1": "EC_4_6_1",
    "BulkEC_2_7_1": "EC_4_7_1",
    "BulkEC_2_8_1": "EC_4_8_1",
    "BulkEC_2_9_1": "EC_4_9_1",
    "T_2_1_1": "TS_4_1_1",
    "T_2_2_1": "TS_4_2_1",
    "T_2_3_1": "TS_4_3_1",
    "T_2_4_1": "TS_4_4_1",
    "T_2_5_1": "TS_4_5_1",
    "T_2_6_1": "TS_4_6_1",
    "T_2_7_1": "TS_4_7_1",
    "T_2_8_1": "TS_4_8_1",
    "T_2_9_1": "TS_4_9_1",
}

# %%
ddf.columns = ddf.columns.str.lower()

for old_col, new_col in mapping.items():
    if str(old_col).lower() in ddf.columns.str.lower():
        if str(new_col).lower() in ddf.columns.str.lower():
            ddf[new_col.lower()] = ddf[[old_col.lower(), new_col.lower()]].max(axis=1)
            ddf = ddf.drop(old_col.lower(), axis=1)
        else:
            ddf = ddf.rename(columns={old_col.lower(): new_col.lower()})

# %%
soildfs

for old_col, new_col in mapping.items():
    if str(old_col).lower() in soildfs.columns.str.lower():
        if str(new_col).lower() in soildfs.columns.str.lower():
            soildfs[new_col.lower()] = soildfs[[old_col.lower(), new_col.lower()]].max(axis=1)
            soildfs = soildfs.drop(old_col.lower(), axis=1)
        else:
            soildfs = soildfs.rename(columns={old_col.lower(): new_col.lower()})
    elif str(old_col).lower()+"_eddy" in soildfs.columns.str.lower():
        print(f"Found {old_col} eddy column")
        if str(new_col).lower()+"_eddy" in soildfs.columns.str.lower():
            soildfs[new_col.lower()] = soildfs[[old_col.lower()+"_eddy", new_col.lower()+"_eddy"]].max(axis=1)
            soildfs = soildfs.drop(old_col.lower()+"_eddy", axis=1)
        else:
            soildfs = soildfs.rename(columns={old_col.lower()+"_eddy": new_col.lower()})
    elif str(new_col).lower()+"_eddy" in soildfs.columns.str.lower():
        if str(new_col).lower() in soildfs.columns.str.lower():
            soildfs[new_col.lower()] = soildfs[[new_col.lower()+"_eddy", new_col.lower()+"_eddy"]].max(axis=1)
            soildfs = soildfs.drop(new_col.lower()+"_eddy", axis=1)
            print(f"Found {new_col} eddy column")
        else:
            print(f"Found {new_col} eddy column")
            soildfs = soildfs.rename(columns={new_col.lower()+"_eddy": new_col.lower()})

# %%
for old_col, new_col in mapping.items():
    if str(old_col).lower()+"_eddy" in soildfs.columns.str.lower().str.strip():
        print(f"Found {old_col} eddy column")

# %%
"swc_4_1_1"

# %%
soildfs.iloc[0:1,:].to_clipboard()

# %%
ddf = ddf.replace(np.nan, 0)

# %%
ddf.to_parquet('../../station_data/all_met_data.parquet')

# %%
ddf = pd.concat(comp_met_df, axis=0)
ddf.index.set_names(['stationid','datetime_start'],inplace=True)
#cdf.rename(columns={'level_0':'stationid'},inplace=True)
#cdf.to_parquet('../station_data/all_data.parquet')
for col in ddf.columns:
    ddf.rename(columns={col:col.lower()},inplace=True)

# %%
ddf[~ddf['vwc_2_7_1'].isna()]

# %%
ddf.iloc[0:1,:].to_clipboard()

# %%
import re

soilcols = [col.lower() for col in am_data.MATH_SOILS_V2]
pattern = re.compile(r"2_1_1|1_2_1|1_1_2")
# Print matching columns
matching_cols = [col for col in soilcols if pattern.search(col)]
# Remove them from the original list
soilcols = [col for col in soilcols if not pattern.search(col)]

        
soildfs = pd.merge(ddf,cdf[soilcols],how='left',on=['stationid','datetime_start'],suffixes=(None,'_eddy'))
soildfs

for col in cdf.columns:
    if col in soilcols:
        cdf.drop(columns=col,inplace=True)  # drop the soil columns from the main dataframe

cdf.to_parquet('../../station_data/all_eddy_data.parquet')

soildfs.to_parquet('../../station_data/all_soil_data.parquet')

ddf.to_parquet('../../station_data/all_met_data.parquet')

# %%
cdf = pd.read_parquet('../../station_data/all_eddy_data.parquet')

# %%
cdf.columns

# %%
soildfs = pd.read_parquet('../../station_data/all_soil_data.parquet')
utd_soilt = soildfs.loc['US-UTD'][['ts_3_1_1','ts_3_2_1','ts_3_3_1']].replace(-9999,np.nan)
utd_soilt = utd_soilt[utd_soilt.index >= '2024-07-01']#.resample('30T').mean()
utd_soilt['ts_3_1_1'].plot()
utd_soilt['ts_3_2_1'].shift(-1).plot()
utd_soilt['ts_3_3_1'].shift(-5).plot()
plt.axvline('2024-07-04 15:00',color='r')
#plt.xlim('2024-07-01','2024-07-08')
#plt.ylim(10,35)
plt.grid(True, which='minor')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from scipy.signal import correlate

# Function to decompose the seasonal component
def extract_seasonal(ts, period):
    decomposition = seasonal_decompose(ts, model='additive', period=period)
    return decomposition.seasonal

# Function to calculate lag between two seasonal series using cross-correlation
def calculate_lag(seasonal1, seasonal2):
    n = len(seasonal1)
    correlation = correlate(seasonal1 - np.mean(seasonal1), seasonal2 - np.mean(seasonal2), mode='full')
    lags = np.arange(-n + 1, n)
    lag = lags[np.argmax(correlation)]
    return lag, correlation, lags

ts1 = utd_soilt['ts_3_2_1']
ts2 = utd_soilt['ts_3_3_1']
#utd_soilt['ts_3_3_1'].shift(-5).plot()


# Extract seasonal components
seasonal1 = extract_seasonal(ts1, period=48)
seasonal2 = extract_seasonal(ts2, period=48)

# Calculate lag
lag, correlation, lags = calculate_lag(seasonal1.dropna(), seasonal2.dropna())

# Output
print(f"Calculated lag: {lag/2} hours")

# Plot seasonal components and correlation
fig, ax = plt.subplots(3, 1, figsize=(10, 8))

seasonal1.plot(ax=ax[0], label='Seasonal Component 1')
seasonal2.plot(ax=ax[0], label='Seasonal Component 2')
ax[0].legend()
ax[0].set_title('Seasonal Components')
ax[0].set_xlim(pd.to_datetime('2024-07-01'),pd.to_datetime('2024-07-08'))
ax[0].grid(True)

ax[1].plot(lags, correlation)
ax[1].set_title('Cross-Correlation')
ax[1].set_xlabel('Lag (hours)')
ax[1].set_ylabel('Correlation')
ax[1].set_xlim(-10, 10)
ax[1].grid(True)

ax[2].plot(seasonal1.index, seasonal1, label='Series 1')
ax[2].plot(seasonal2.index + pd.Timedelta(hours=lag/2), seasonal2, label='Series 2 (Shifted)')
ax[2].legend()
ax[2].set_title(f'Series alignment (Lag: {lag/2} hours)')
ax[2].set_xlim(pd.to_datetime('2024-07-01'),pd.to_datetime('2024-07-08'))
ax[2].grid(True)
plt.tight_layout()
plt.show()

# %%
cdf = pd.read_parquet('../../station_data/all_eddy_data.parquet')
ddf = pd.read_parquet('../../station_data/all_met_data.parquet')

for col in cdf.columns:
    if col in ddf.columns:
        print(col)

# %%
ddf.head(10).to_clipboard()

# %%
series = ddf.loc['US-UTD','t_si111_body'].replace(-9999,np.nan)
series.plot()
series.diff().plot()
new_series = series[series.diff()<2].diff().cumsum()
new_series.plot()

# %%
config = configparser.ConfigParser()

config.read('../../secrets/config.ini')

from sqlalchemy import create_engine
import urllib.parse
host = config['DEFAULT']['ip']
pw = config['DEFAULT']['pw']
user = config['DEFAULT']['login']

encoded_password = urllib.parse.quote_plus(pw)

def postconn_et(encoded_password, host='localhost',user='postgres',port='5432',db='groundwater', schema = 'groundwater'):
    connection_text = "postgresql+psycopg2://{:}:{:}@{:}:{:}/{:}?gssencmode=disable".format(user,encoded_password,host,port,db)
    return create_engine(connection_text, connect_args={'options': '-csearch_path={}'.format(schema)})


engine = postconn_et(encoded_password, host=host, user=user)

# %%
cdf.to_sql(name = 'amfluxeddy',
           schema='groundwater',
           con=engine,
           if_exists='replace',
           chunksize=2000)

# %%
for col in soildfs.columns:
    print(f"amfluxmet.{col},")

# %%
soildfs.to_sql(name = 'amfluxmet',
           schema='groundwater',
           con=engine,
           if_exists='replace',
           chunksize=2000)
